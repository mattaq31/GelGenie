# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/matt/Documents/PhD/research_output/Automatic_Gel_Analyzer/segmentation_results/unet++_august9_testing/ladder_2_full_data.csv')
df = pd.read_csv('/Users/matt/Documents/PhD/research_output/Automatic_Gel_Analyzer/segmentation_results/unet++_august9_testing/ladder_2_adaptive_background.csv')

new_cols = ['ga_ladder_1',
             'ga_ladder_2',
             'ga_ladder_3',
             'ga_ladder_4',
             'ga_ladder_1_bc',
             'ga_ladder_2_bc',
             'ga_ladder_3_bc',
             'ga_ladder_4_bc',
             'seg_ladder_1',
             'seg_ladder_2',
             'seg_ladder_3',
             'seg_ladder_4',
             'seg_ladder_1_bc',
             'seg_ladder_2_bc',
             'seg_ladder_3_bc',
             'seg_ladder_4_bc',
             'Reference Data']
df = df[new_cols]

# %%
df
# Out:
#     ga_ladder_1  ga_ladder_2  ga_ladder_3  ga_ladder_4  ga_ladder_1_bc  \
# 0          1454         1833         2033         2677             529
# 1          1248         1717         2092         2412             387
# 2          1723         2164         2655         3065             602
# 3          1497         1817         2286         2495             495
# 4          1557         1985         2416         2832             352
# 5          2620         3244         3868         4359            1440
# 6          1773         2189         2759         3101             532
# 7          1875         2567         3362         3767             673
# 8          1942         2466         2854         3278             536
# 9          3039         2994         4450         5068            1584
# 10         1202         1754         1914         2250             221
# 11         1479         1845         2218         2647             203
# ...

# %%
757.5*88.3399
# Out:
# 66917.47425

# %%
ref_pos = 7
ref_data = [40, 40, 48, 40, 32, 120, 40, 57, 45, 122, 34, 31, 27, 23, 124, 49, 37, 32, 61]

tdf = df.divide(df.iloc[ref_pos]).multiply(ref_data[ref_pos])

# %%
ref_pos = 4
ref_data = [40, 40, 48, 40, 32, 120, 40, 57, 45, 122, 34, 31, 27, 23, 124, 49, 37, 32, 61]

tdf = df.divide(df.iloc[ref_pos]).multiply(ref_data[ref_pos])

bars = plt.bar(list(tdf.columns), tdf.subtract(ref_data,axis=0).abs().mean(axis=0))
plt.xticks(rotation=90)

for b in bars[0:4]:
    b.set_color('green')

for b in bars[4:8]:
    b.set_color('red')

for b in bars[8:12]:
    b.set_color('purple')    
# bars[1].set_color('black')
# bars[2].set_color('red')
pass

# %%
fig, ax = plt.subplots(figsize=(15,5))
tdf.plot(ax=ax)
pass

# %%
l1 = tdf.filter(regex='ladder_1')
l1['Reference Data'] = ref_data
fig, ax = plt.subplots(figsize=(15,5))
l1.plot(ax=ax)
# Out:
# /var/folders/4x/_gjrrkj918v37xmw7d8n_p2h0000gn/T/ipykernel_86556/2121134607.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l1['Reference Data'] = ref_data
# <AxesSubplot:>

# %%
l2 = tdf.filter(regex='ladder_2')
l2['Reference Data'] = ref_data
fig, ax = plt.subplots(figsize=(15,5))
l2.plot(ax=ax)
# Out:
# /var/folders/4x/_gjrrkj918v37xmw7d8n_p2h0000gn/T/ipykernel_86556/3561031182.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l2['Reference Data'] = ref_data
# <AxesSubplot:>

# %%
l3 = tdf.filter(regex='ladder_3')
l3['Reference Data'] = ref_data
fig, ax = plt.subplots(figsize=(15,5))
l3.plot(ax=ax)
# Out:
# /var/folders/4x/_gjrrkj918v37xmw7d8n_p2h0000gn/T/ipykernel_86556/2992189294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l3['Reference Data'] = ref_data
# <AxesSubplot:>

# %%
l4 = tdf.filter(regex='ladder_4')
l4['Reference Data'] = ref_data
fig, ax = plt.subplots(figsize=(15,5))
l4.plot(ax=ax)
# Out:
# /var/folders/4x/_gjrrkj918v37xmw7d8n_p2h0000gn/T/ipykernel_86556/1588175085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l4['Reference Data'] = ref_data
# <AxesSubplot:>
